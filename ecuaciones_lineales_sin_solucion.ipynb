# %% [markdown]
# ### Generacion de graficos debajo de las celdas

# %%
# %matplotlib inline

# %% [markdown]
# ### Importamos librerias

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-6,-6)

y_1 =  3*x + 5
y_2 = -x + 3
y_3 = 2*x + 1

# %%
plt.figure()

plt.plot(x, y_1)
plt.plot(x, y_2)
plt.plot(x, y_3)

plt.xlim(-8,8)
plt.ylim(-8,8)

plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')

plt.show()
# Out:
# <div id='aaaa1b65-5249-4784-ad01-b339d69d6cbc'></div>
# <div id='244ed23e-d233-4f62-b62a-ed7f5a431fe5'></div>

# %%
x = np.arange(-6,6)


y_2 = -1*x +3
y_3 = 2*x +1

# %%
plt.figure()

plt.plot(x, y_2)
plt.plot(x, y_3)

plt.xlim(-8,8)
plt.ylim(-8,8)

plt.axvline(x=0, color='grey')
plt.axhline(y=0, color='grey')

plt.show()
