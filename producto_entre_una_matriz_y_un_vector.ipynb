# %%
import numpy as np

# %%
escalar = 5.679
vector = np.array([2,3])
matriz = np.array([[1,2],[3,4],[5,6]])

# %%
A = matriz * vector

# %%
print(A)
# Out:
# [[ 2  6]
#  [ 6 12]
#  [10 18]]

# %% [markdown]
# ### Producto interno de la matriz

# %%
B = matriz.dot (vector)

# %%
print(B)
# Out:
# [ 8 18 28]

# %%
C = np.dot(matriz, vector)
print(C)
# Out:
# [ 8 18 28]
