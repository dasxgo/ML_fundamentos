# %%
import numpy as np

# %%
escalar = 5.679
vector = np.array([3,4,5,6])
matriz = np.array([[1,2],[3,4],[5,6]])
tensor = np.array([
    [[1,2,3,30],[4,5,6,31],[7,8,932]],
    [[1,2,3,30],[4,5,6,31],[7,8,932]],
    [[1,2,3,30],[4,5,6,31],[7,8,932]],
])
# Out:
# <ipython-input-5-a2a0b9f892aa>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   tensor = np.array([

# %%
vector_t =vector.T
vector_t
# Out:
# array([3, 4, 5, 6])

# %%
matriz_t = matriz.T
matriz_t
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %%
(matriz.shape)
# Out:
# (3, 2)

# %%
(matriz_t.shape)
# Out:
# (2, 3)

# %%
tensor_t = tensor.T
tensor_t
# Out:
# array([[list([1, 2, 3, 30]), list([1, 2, 3, 30]), list([1, 2, 3, 30])],
#        [list([4, 5, 6, 31]), list([4, 5, 6, 31]), list([4, 5, 6, 31])],
#        [list([7, 8, 932]), list([7, 8, 932]), list([7, 8, 932])]],
#       dtype=object)

# %%
tensor
# Out:
# array([[list([1, 2, 3, 30]), list([4, 5, 6, 31]), list([7, 8, 932])],
#        [list([1, 2, 3, 30]), list([4, 5, 6, 31]), list([7, 8, 932])],
#        [list([1, 2, 3, 30]), list([4, 5, 6, 31]), list([7, 8, 932])]],
#       dtype=object)

# %%
matriz_t_t = matriz_t.T
matriz_t_t
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
matriz
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
A = np.array([[1,2],[3,4],[5,6]])
B = np.array([[6,5],[4,3],[2,1]])
C = A+B
print(A)
print(B)
print(C)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [[6 5]
#  [4 3]
#  [2 1]]
# [[7 7]
#  [7 7]
#  [7 7]]

# %%
D = matriz + escalar
print(D)
# Out:
# [[ 6.679  7.679]
#  [ 8.679  9.679]
#  [10.679 11.679]]
